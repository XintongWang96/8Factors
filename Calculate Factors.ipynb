# %% [markdown]
# ### Factors Data Loads

# %%
import pickle

# %%
from jaqs_fxdayu.util import dp
from jaqs.data.dataapi import DataApi


api = DataApi(addr='tcp://data.tushare.org:8910')
api.login("13662241013", 
          'eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MTc2NDQzMzg5MTIiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTM2NjIyNDEwMTMifQ.sVIzI5VLqq8fbZCW6yZZW0ClaCkcZpFqpiK944AHEow'
)

start = 20150101
end = 20180101
SH_id = dp.index_cons(api, "000300.SH", start, end)
SZ_id = dp.index_cons(api, "000905.SH", start, end)

stock_symbol = list(set(SH_id.symbol)|set(SZ_id.symbol))

import os
import numpy as np
import pandas as pd
import jaqs_fxdayu
jaqs_fxdayu.patch_all()
from jaqs_fxdayu.data import DataView
from jaqs_fxdayu.data.dataservice import LocalDataService
from jaqs_fxdayu.data.dataservice import RemoteDataService

import warnings
warnings.filterwarnings("ignore")

#--------------------------------------------------------
#define


factor_list  = ['fcffps','net_cash_flows_oper_act','lt_borrow','st_borrow','LCAP','end_bal_cash']
check_factor = ','.join(factor_list)

dataview_folder = r'D:/data'
ds = LocalDataService(fp = dataview_folder)

dv_props = {'start_date': start, 'end_date': end, 'symbol':','.join(stock_symbol),
         'fields': check_factor,
         'freq': 1,
        'timeout':600,  
         "prepare_fields": True}

dv = DataView()

dv.init_from_config(dv_props, data_api=ds)
dv.prepare_data()
# Out:
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'vwap_adj,close_adj,open,high_adj,trade_status,low,close,trade_date,symbol,high,low_adj,open_adj,vwap'}
# 下载进度647/1051.
# 当前请求daily...
# {'adjust_mode': 'post', 'fields': 'open,low,close,high,vwap,symbol,trade_date'}
# 下载进度647/1051.
# 当前请求query...
# {'fields': 'LCAP', 'view': 'factor'}
# 下载进度647/1051.
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000562.SZ, 000748.SZ, 600005.SH, 600832.SH, 601299.SH
# Query data - daily fields prepared.
# WARNING: some data is unavailable:
#     At fields
# Query data - quarterly fields prepared.
# Query instrument info...
# Query adj_factor...
# Data has been successfully prepared.

# %%
# total market value
data_config = {
    "remote.data.address": "tcp://data.tushare.org:8910",
    "remote.data.username": "13662241013",
    "remote.data.password": "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MTc2NDQzMzg5MTIiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTM2NjIyNDEwMTMifQ.sVIzI5VLqq8fbZCW6yZZW0ClaCkcZpFqpiK944AHEow"
}
ds1 = RemoteDataService()
ds1.init_from_config(data_config)




dv.add_field('total_mv',ds1)
dv.add_field('ncf_oper_ttm',ds1)
#dv.save_dataview('totalmv_data')
# Out:
# Begin: DataApi login 13662241013@tcp://data.tushare.org:8910
#     login success
# '0,'

# %%
#dv.get_ts('total_mv')
dv.get_ts('ncf_oper_ttm').head()
# Out:
# symbol         000001.SZ     000002.SZ    000006.SZ    000008.SZ  \
# trade_date
# 20150105   -1.425800e+10  3.118913e+10 -939208820.9  70210751.65
# 20150106   -1.425800e+10  3.118913e+10 -939208820.9  70210751.65
# 20150107   -1.425800e+10  3.118913e+10 -939208820.9  70210751.65
# 20150108   -1.425800e+10  3.118913e+10 -939208820.9  70210751.65
# 20150109   -1.425800e+10  3.118913e+10 -939208820.9  70210751.65
#
# symbol         000009.SZ     000012.SZ     000021.SZ     000024.SZ  \
# trade_date
# 20150105    4.680565e+08  1.559142e+09  2.713909e+08 -5.792452e+09
# 20150106    4.680565e+08  1.559142e+09  2.713909e+08 -5.792452e+09
# 20150107    4.680565e+08  1.559142e+09  2.713909e+08 -5.792452e+09
# 20150108    4.680565e+08  1.559142e+09  2.713909e+08 -5.792452e+09
# 20150109    4.680565e+08  1.559142e+09  2.713909e+08 -5.792452e+09
#
# symbol       000025.SZ     000027.SZ      ...       603833.SH  603858.SH  \
# trade_date                                ...
# 20150105   -6133166.47  3.262653e+09      ...             NaN        NaN
# 20150106   -6133166.47  3.262653e+09      ...             NaN        NaN
# 20150107   -6133166.47  3.262653e+09      ...             NaN        NaN
# 20150108   -6133166.47  3.262653e+09      ...             NaN        NaN
# 20150109   -6133166.47  3.262653e+09      ...             NaN        NaN
#
# symbol      603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  603888.SH  \
# trade_date
# 20150105          NaN        NaN        NaN        NaN        NaN        NaN
# 20150106          NaN        NaN        NaN        NaN        NaN        NaN
# 20150107          NaN        NaN        NaN        NaN        NaN        NaN
# 20150108          NaN        NaN        NaN        NaN        NaN        NaN
# 20150109          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603899.SH     603993.SH
# trade_date
# 20150105          NaN  2.079564e+09
# 20150106          NaN  2.079564e+09
# 20150107          NaN  2.079564e+09
# 20150108          NaN  2.079564e+09
# 20150109          NaN  2.079564e+09
#
# [5 rows x 1051 columns]

# %% [markdown]
# ### Spearman_check

# %%
import scipy.stats as scst
import jaqs.util as jutill


def spearman_factor(factor_u='factor_u', factor_j='factor_j', start=20160101, symbol=stock_symbol):
    factors = dict()
    factors["factor_u"] = dv.get_ts(factor_u).loc[start:][stock_symbol].stack()
    factors["factor_j"] = dv.get_ts(factor_j).loc[start:][stock_symbol].stack()

    factors_df = pd.concat(factors.values(),axis=1)
    factors_df.columns = factors.keys()
    factors_df = jutill.fillinf(factors_df).dropna()

    # 两个因子的spearman相关性
    def get_factors_daily_corr(factors_df,
                               f1="factor_u",
                               f2="factor_j"):
        def _cal_corr(df):
            return scst.spearmanr(df[f1], df[f2])[0]

        result = factors_df.groupby(['trade_date']).apply(_cal_corr)
        result = pd.DataFrame(result)
        result.columns = ['spearmanr']
        return result
 
    result = get_factors_daily_corr(factors_df,"factor_u","factor_j")
    t_stat, p_value = scst.ttest_1samp(result, 0)
    return result.mean(), p_value # 相关关系均值,相关关系均值的ｔ统计量的p_value

# %% [markdown]
# ## 因子一
#
# ### EnterpriseFCFPS--企业每股自由现金流量
#
# #### 计算方法：直接读取

# %%
EnterpriseFCFPS = dv.add_formula('EnterpriseFCFPS_J',"fcffps",is_quarterly = False, add_data = True)
dv.add_field('fcffps',ds)
print(spearman_factor(factor_u='fcffps', factor_j='EnterpriseFCFPS_J', start=20160101, symbol=stock_symbol))
# Out:
# Field name [fcffps] already exists.
# (spearmanr    0.485583
# dtype: float64, array([ 0.01588577]))

# %%
dv.get_ts('fcffps').head()
# Out:
# symbol      000001.SZ  000002.SZ  000006.SZ  000008.SZ  000009.SZ  000012.SZ  \
# trade_date
# 20150105          0.0     1.3685    -0.7609     0.0996    -0.4791    -0.2771
# 20150106          0.0     1.3685    -0.7609     0.0996    -0.4791    -0.2771
# 20150107          0.0     1.3685    -0.7609     0.0996    -0.4791    -0.2771
# 20150108          0.0     1.3685    -0.7609     0.0996    -0.4791    -0.2771
# 20150109          0.0     1.3685    -0.7609     0.0996    -0.4791    -0.2771
#
# symbol      000021.SZ  000024.SZ  000025.SZ  000027.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20150105      -0.2356    -1.0599    -0.4985     0.3387    ...         0.0348
# 20150106      -0.2356    -1.0599    -0.4985     0.3387    ...         0.0348
# 20150107      -0.2356    -1.0599    -0.4985     0.3387    ...         0.0348
# 20150108      -0.2356    -1.0599    -0.4985     0.3387    ...         0.0348
# 20150109      -0.2356    -1.0599    -0.4985     0.3387    ...         0.0348
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20150105          NaN        NaN        NaN    -0.4468        NaN     -0.661
# 20150106          NaN        NaN        NaN    -0.4468        NaN     -0.661
# 20150107          NaN        NaN        NaN    -0.4468        NaN     -0.661
# 20150108          NaN        NaN        NaN    -0.4468        NaN     -0.661
# 20150109          NaN        NaN        NaN    -0.4468        NaN     -0.661
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20150105          NaN        NaN     0.2194
# 20150106          NaN     0.1177     0.2194
# 20150107          NaN     0.1177     0.2194
# 20150108          NaN     0.1177     0.2194
# 20150109          NaN     0.1177     0.2194
#
# [5 rows x 1051 columns]

# %% [markdown]
# ## 因子二
# ### CFO2EV-- 经营活动产生的现金流量净额与企业价值之比
# ### 计算方法：
# #### CFO2EV = NOCF/EV=NOCF/(LTL+STL+MarketValue-N_CE)

# %%
(ncf_oper_ttm,lt_borrow,st_borrow,total_mv,end_bal_cash)=(dv.get_ts(x) 
                                                         for x in ('ncf_oper_ttm','lt_borrow','st_borrow','total_mv','end_bal_cash'))
CFO2EV_J=ncf_oper_ttm/(lt_borrow+st_borrow+total_mv-end_bal_cash) 
#CFO2EV = dv.add_formula('CFO2EV_J',"ncf_oper_ttm/(lt_borrow+st_borrow+total_mv-end_bal_cash)",is_quarterly=True, add_data=True)
CFO2EV=dv.append_df(CFO2EV_J,'CFO2EV_J')
dv.add_field('CFO2EV',ds)
print(spearman_factor(factor_u='CFO2EV', factor_j='CFO2EV_J', start=20160101, symbol=stock_symbol))
# Out:
# Query data - query...
# 当前请求query...
# {'fields': 'CFO2EV', 'view': 'factor'}
# 下载进度647/1051.
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000562.SZ, 000748.SZ, 600005.SH, 600832.SH, 601299.SH
# Query data - daily fields prepared.
# (spearmanr    0.349119
# dtype: float64, array([ 0.02938252]))

# %%
#dv.get_ts('ncf_oper_ttm')
#dv.get_ts('end_bal_cash')
#print(type(dv.get_ts('ncf_oper_ttm')))

# %% [markdown]
# ## 因子三
# ### GainVariance20--20日收益方差
# ### 计算方法：
# #### GV(r) = E(r-E(r)|r>=0)^2 = E(r^2|r>=0)-E(r|r>=0)^2

# %%
dv.add_field('RVI',ds)
# Out:
# Query data - query...
# 当前请求query...
# {'fields': 'RVI', 'view': 'factor'}
# 下载进度647/1051.
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000562.SZ, 000748.SZ, 600005.SH, 600832.SH, 601299.SH
# Query data - daily fields prepared.
# True

# %%
dv.add_field('close_adj')
# Out:
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'close_adj,trade_status,close,trade_date,symbol'}
# 下载进度647/1051.
# 当前请求daily...
# {'adjust_mode': 'post', 'fields': 'close,symbol,trade_date'}
# 下载进度647/1051.
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000562.SZ, 000748.SZ, 600005.SH, 600832.SH, 601299.SH
# Query data - daily fields prepared.
# True

# %%
dv.add_formula('ret_f','Return(close_adj,20)',is_quarterly = False,add_data = True)

dv.get_ts('ret_f').head()
# Out:
# symbol      000001.SZ  000002.SZ  000006.SZ  000008.SZ  000009.SZ  000012.SZ  \
# trade_date
# 20150105     0.147564   0.275449  -0.008403  -0.063848  -0.071685   0.048220
# 20150106     0.086029   0.253054  -0.007246  -0.036203  -0.029963   0.089180
# 20150107     0.016415   0.156911   0.004392   0.058294   0.000751   0.033257
# 20150108     0.091174   0.190018   0.027273   0.063221   0.025346   0.075383
# 20150109     0.062720   0.125523  -0.001490   0.015337  -0.049780  -0.007813
#
# symbol      000021.SZ  000024.SZ  000025.SZ  000027.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20150105    -0.081582        NaN  -0.187251   0.139139    ...            NaN
# 20150106     0.018519        NaN  -0.125523   0.108949    ...            NaN
# 20150107     0.039947        NaN  -0.115188   0.115710    ...            NaN
# 20150108     0.116737        NaN  -0.060329   0.143719    ...            NaN
# 20150109     0.052917        NaN  -0.085868   0.036827    ...            NaN
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20150105          NaN        NaN        NaN        NaN        NaN        NaN
# 20150106          NaN        NaN        NaN        NaN        NaN        NaN
# 20150107          NaN        NaN        NaN        NaN        NaN        NaN
# 20150108          NaN        NaN        NaN        NaN        NaN        NaN
# 20150109          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20150105          NaN        NaN  -0.025304
# 20150106          NaN        NaN   0.069040
# 20150107          NaN        NaN   0.103337
# 20150108          NaN        NaN   0.151270
# 20150109          NaN        NaN   0.111111
#
# [5 rows x 1051 columns]

# %%
GainVariance20 = dv.add_formula('GainVariance20_J','If(ret_f>0,250*((Ts_Mean(ret_f^2,20)-(Ts_Mean(ret_f,20))^2)),0)',is_quarterly=False,add_data=True)
# Out:
# Field [GainVariance20_J] is overwritten.

# %%
dv.get_ts('GainVariance20_J').head()
# Out:
# symbol      000001.SZ  000002.SZ  000006.SZ  000008.SZ  000009.SZ  000012.SZ  \
# trade_date
# 20150105     1.704767   0.986857   0.000000   0.000000   0.000000   0.323589
# 20150106     2.185723   1.015071   0.000000   0.000000   0.000000   0.322542
# 20150107     2.891565   0.951789   0.766204   0.331299   1.660101   0.341083
# 20150108     3.225378   0.951707   0.730510   0.357128   1.660281   0.334177
# 20150109     3.671125   0.995349   0.000000   0.360087   0.000000   0.000000
#
# symbol      000021.SZ  000024.SZ  000025.SZ  000027.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20150105     0.000000        NaN        0.0   2.534063    ...            NaN
# 20150106     0.370436        NaN        0.0   2.863935    ...            NaN
# 20150107     0.434268        NaN        0.0   3.215183    ...            NaN
# 20150108     0.694883        NaN        0.0   3.412584    ...            NaN
# 20150109     0.764714        NaN        0.0   4.163966    ...            NaN
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20150105          NaN        NaN        NaN        NaN        NaN        NaN
# 20150106          NaN        NaN        NaN        NaN        NaN        NaN
# 20150107          NaN        NaN        NaN        NaN        NaN        NaN
# 20150108          NaN        NaN        NaN        NaN        NaN        NaN
# 20150109          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20150105          NaN        NaN   0.000000
# 20150106          NaN        NaN   3.903037
# 20150107          NaN        NaN   3.579136
# 20150108          NaN        NaN   3.573375
# 20150109          NaN        NaN   3.494355
#
# [5 rows x 1051 columns]

# %%
print(spearman_factor(factor_u='RSI', factor_j='GainVariance20_J', start=20160101, symbol=stock_symbol))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-59adeb2c2164> in <module>()
# ----> 1 print(spearman_factor(factor_u='RSI', factor_j='GainVariance20_J', start=20160101, symbol=stock_symbol))
#
# <ipython-input-11-129ecb6e7b49> in spearman_factor(factor_u, factor_j, start, symbol)
#       5 def spearman_factor(factor_u='factor_u', factor_j='factor_j', start=20160101, symbol=stock_symbol):
#       6     factors = dict()
# ----> 7     factors["factor_u"] = dv.get_ts(factor_u).loc[start:][stock_symbol].stack()
#       8     factors["factor_j"] = dv.get_ts(factor_j).loc[start:][stock_symbol].stack()
#       9
#
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2098             return self.take(indexer, axis=0, convert=False)
#    2099         else:
# -> 2100             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2101             return self.take(indexer, axis=1, convert=True)
#    2102
#
# E:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['002241.SZ' '601808.SH' '600917.SH' ..., '600655.SH' '600816.SH'\n '002223.SZ'] not in index"

# %% [markdown]
# ## 因子四
# ### Cmra

# %%
dv.add_formula('ret','Return(close_adj,1)',is_quarterly=False,add_data=True)
dv.add_formula('ret_f','ret+1',is_quarterly=False,add_data=True)
dv.add_formula('vl','If(volume>0,1,0)',is_quarterly=False,add_data=True)
cmraMx = dv.add_formula('cmraMx0','Ts_Product(ret_f*vl,24)',is_quarterly=False,add_data=True)
cmraMn = dv.add_formula('cmraMn0','cmraMx0',is_quarterly=False,add_data=True)
# step max
for k in range(23):
    temp_prod = dv.add_formula('temp_prod','Ts_Product(Delay(ret_f*vl,%s),%s)'%(k+1,24-k),is_quarterly=False,add_data=True)
    cmra_Mx = dv.add_formula('cmraMx%s'%(k+1),'Max(cmraMx%s,temp_prod)'%(k),is_quarterly=False,add_data=True)
    cmra_Mn = dv.add_formula('cmraMn%s'%(k+1),'Min(cmraMn%s,temp_prod)'%(k),is_quarterly=False,add_data=True)
Cmra = dv.add_formula('Cmra_J','Log(cmraMx23)-Log(cmraMn23)',is_quarterly=False,add_data=True)
# Out:
# Field [ret_f] is overwritten.
# Variable [volume] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'volume,trade_status,trade_date,symbol'}
# 下载进度647/1051.
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000562.SZ, 000748.SZ, 600005.SH, 600832.SH, 601299.SH
# Query data - daily fields prepared.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.
# Field [temp_prod] is overwritten.

# %%
print(spearman_factor(factor_u ='CMRA',factor_j = 'Cmra_J',start = 20160101,symbol = stock_symbol) )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-5bf3fce8ab08> in <module>()
# ----> 1 print(spearman_factor(factor_u ='CMRA',factor_j = 'Cmra_J',start = 20160101,symbol = stock_symbol) )
#
# <ipython-input-11-129ecb6e7b49> in spearman_factor(factor_u, factor_j, start, symbol)
#       5 def spearman_factor(factor_u='factor_u', factor_j='factor_j', start=20160101, symbol=stock_symbol):
#       6     factors = dict()
# ----> 7     factors["factor_u"] = dv.get_ts(factor_u).loc[start:][stock_symbol].stack()
#       8     factors["factor_j"] = dv.get_ts(factor_j).loc[start:][stock_symbol].stack()
#       9
#
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2098             return self.take(indexer, axis=0, convert=False)
#    2099         else:
# -> 2100             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2101             return self.take(indexer, axis=1, convert=True)
#    2102
#
# E:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['002241.SZ' '300133.SZ' '601808.SH' ..., '600606.SH' '600816.SH'\n '600317.SH'] not in index"

# %% [markdown]
# ### 因子五
# ### TVSTD--Total Market Value与Standard Deviation的比值
# ### 计算方法：
# #### Total MV/ Standard Deviation

# %%
# dv.add_field('volume',ds)
# dv.get_ts('volume').head()

# %%
dv.add_formula('turn_over_value','close_adj*volume/Pow(10,6)',is_quarterly=False,add_data=True)
TVSTD6=dv.add_formula('TVSTD6_J','StdDev(turn_over_value,24)',is_quarterly = False,add_data = True)

# %%
dv.add_field('TVSTD6',ds)
# Out:
# Query data - query...
# 当前请求query...
# {'fields': 'TVSTD6', 'view': 'factor'}
# 下载进度647/1051.
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000562.SZ, 000748.SZ, 600005.SH, 600832.SH, 601299.SH
# Query data - daily fields prepared.
# True

# %%
print(spearman_factor(factor_u ='TVSTD6',factor_j = 'TVSTD6_J',start = 20160101,symbol = stock_symbol))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-ff2818a9cb37> in <module>()
# ----> 1 print(spearman_factor(factor_u ='TVSTD6',factor_j = 'TVSTD6_J',start = 20160101,symbol = stock_symbol))
#
# <ipython-input-11-129ecb6e7b49> in spearman_factor(factor_u, factor_j, start, symbol)
#       5 def spearman_factor(factor_u='factor_u', factor_j='factor_j', start=20160101, symbol=stock_symbol):
#       6     factors = dict()
# ----> 7     factors["factor_u"] = dv.get_ts(factor_u).loc[start:][stock_symbol].stack()
#       8     factors["factor_j"] = dv.get_ts(factor_j).loc[start:][stock_symbol].stack()
#       9
#
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2098             return self.take(indexer, axis=0, convert=False)
#    2099         else:
# -> 2100             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2101             return self.take(indexer, axis=1, convert=True)
#    2102
#
# E:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['002241.SZ' '601808.SH' '600917.SH' ..., '600655.SH' '600816.SH'\n '002223.SZ'] not in index"

# %% [markdown]
# ## 因子六七八
# ### Alpha12 Alpha22 Alpha76
# ### 计算方式：

# %%
alpha12=dv.add_formula('alpha12','(Rank((open_adj- (Ts_Sum(vwap_adj, 10) / 10)))) * (-1 * (Rank(Abs((close_adj - vwap_adj)))))',is_quarterly=False,add_data=True)
# Out:
# Field [alpha12] is overwritten.

# %%
alpha22 = dv.add_formula('alpha22','Ts_Mean(((close_adj-Ts_Mean(close_adj,6))/Ts_Mean(close_adj,6)-Delay((close_adj-Ts_Mean(close_adj,6))/Ts_Mean(close_adj,6),3)),12)',is_quarterly=False,add_data=True)
# Out:
# Field [alpha22] is overwritten.

# %%
alpha76 = dv.add_formula('alpha76','StdDev(Abs((close_adj/Delay(close_adj,1)-1))/volume,20)/Ts_Mean(Abs((close_adj/Delay(close_adj,1)-1))/volume,20)',is_quarterly=False,add_data=True)
# Out:
# Field [alpha76] is overwritten.

# %%
# print(type(dv.get_ts('alpha76')))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
alpha_pn = pd.Panel({'alpha{}'.format(i) : dv.get_ts('alpha{}'.format(i)) for i in [12,22,76]}).to_frame()
print(alpha_pn.tail())
# Out:
#                        alpha12   alpha22   alpha76
# trade_date symbol
# 20171229   603883.SH -198828.0  0.003887  0.723483
#            603885.SH -127617.0 -0.004951  0.632631
#            603888.SH -109484.0 -0.010172  0.478991
#            603899.SH -223539.0 -0.013247  0.795689
#            603993.SH -194880.0  0.004634  0.675480

# %%
#dv.get_ts('alpha12').head()
#dv.get_ts('alpah22').head()
dv.get_ts('alpha76').head()
# Out:
# symbol      000001.SZ  000002.SZ  000006.SZ  000008.SZ  000009.SZ  000012.SZ  \
# trade_date
# 20150105     0.575737   0.531286   0.598917        NaN        NaN   0.763656
# 20150106     0.587140   0.509661   0.599561        NaN        NaN   0.830805
# 20150107     0.590186   0.550838   0.608258        NaN        NaN   0.842261
# 20150108     0.586658   0.551716   0.606275        NaN        NaN   0.840853
# 20150109     0.625374   0.600290   0.601978        NaN        NaN   0.807022
#
# symbol      000021.SZ  000024.SZ  000025.SZ  000027.SZ    ...      603833.SH  \
# trade_date                                                ...
# 20150105     0.477831        NaN   0.735708   0.841107    ...            NaN
# 20150106     0.474777        NaN   0.743065   0.873208    ...            NaN
# 20150107     0.439112        NaN   0.747938   0.850836    ...            NaN
# 20150108     0.479091        NaN   0.765317   0.842146    ...            NaN
# 20150109     0.461878        NaN   0.788441   0.841663    ...            NaN
#
# symbol      603858.SH  603866.SH  603868.SH  603877.SH  603883.SH  603885.SH  \
# trade_date
# 20150105          NaN        NaN        NaN        NaN        NaN        NaN
# 20150106          NaN        NaN        NaN        NaN        NaN        NaN
# 20150107          NaN        NaN        NaN        NaN        NaN        NaN
# 20150108          NaN        NaN        NaN        NaN        NaN        NaN
# 20150109          NaN        NaN        NaN        NaN        NaN        NaN
#
# symbol      603888.SH  603899.SH  603993.SH
# trade_date
# 20150105          NaN        NaN   0.656587
# 20150106          NaN        NaN   0.698262
# 20150107          NaN        NaN   0.649299
# 20150108          NaN        NaN   0.660428
# 20150109          NaN        NaN   0.719110
#
# [5 rows x 1051 columns]

# %%
dv.save_dataview('D:/data/alpha')
# Out:
# Store data...
# Dataview has been successfully saved to:
# D:\data\alpha
#
# You can load it with load_dataview('D:\data\alpha')

# %%
pwd
# Out:
# 'C:\\Users\\Administrator\\Desktop\\云实习--王馨桐\\Factors8'
